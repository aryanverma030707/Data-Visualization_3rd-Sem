# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
def Sum(a,b):
    return(a+b)
a=int(input("Enter the First number "))
b= int(input("Enter the 2nd number"))
result=Sum(a,b)
print(f"The sum of {a} and {b} is {result}")

# %%
def Sum(a,b):
    return(a+b)
a=int(input("Enter the First number "))
b= int(input("Enter the 2nd number"))
result=Sum(a,b)
print(f"The sum of a and b is ",result)

# %%
def even_odd(n):
    if n % 2 == 0:
        print("Even")
    else:
        print("Odd")

even_odd(10)
even_odd(7)

# %% [markdown]
# Parameters vs. Arguments
#
# These two terms are often used interchangeably, but they mean different things — and knowing the distinction will make you sound (and think) like a precise programmer.
#
# Parameter: The variable name listed in the function's definition. It's a placeholder.
# Argument: The actual value you pass into the function when you call it.

# %% [markdown]
# ****Argument Types**
#
# Python offers several flexible ways to pass arguments into a function. Understanding each type lets you design functions that are both powerful and easy to use.**

# %% [markdown]
# **Positional Arguments  =
# The most common type — arguments are matched to parameters based on their order.**

# %%
def describe_pet(animal, name):
    print(f"{name} is a {animal}.")

describe_pet("dog", "Rex")   # animal="dog", name="Rex"

# %%
import math

def area_circle(r):
    return math.pi * r * r

r = float(input("Enter radius: "))

print("Area of circle =", area_circle(r))

# %%
import math

def area_circle(r):
    return (3.14 * r * r)

r = float(input("Enter radius: "))

print("Area of circle =", area_circle(r))

# %% [markdown]
# ***Keyword Arguments** =
# You can explicitly name which parameter each argument belongs to. This removes ambiguity and lets you pass arguments out of order*
# .

# %%
decribe_pet(name="Rex", animal="dog")  # Order no longer matters

# %% [markdown]
# ****Variable-Length Arguments: *args and*** **kwargs**
#
# Sometimes you don't know in advance how many arguments will be passed. Python handles this with two special syntaxes.
#
# ***args** (non-keyword variable arguments) Collects any number of positional arguments into a tuple.
#
# ****kwargs** (keyword variable arguments) Collects any number of keyword arguments into a dictionary.
#
# python

# %%
def function(*args):
    for i in args:
        print(i)

# %%
def test(*args):
    print(type(args))

test(10, 20, 30)

# %%
def add(*args):
    sum = 0
    for i in args:
        sum += i
    return sum

print(add(10, 20, 30))

# %%
def add(a,b,c):
    return(a+b+c)

a=int(input("Enter the 1st no="))
b=int(input("Enter the 2nd no="))
c=int(input("Enter the 3rd no="))
result=add(a,b,c)
print(result)
print(type(result))

# %% [markdown]
# Keyword arguments are arguments you pass to a function by explicitly naming the parameter they belong to, using parameter=value syntax — instead of relying on position/order.

# %%
def add(**kwargs):
    return sum(kwargs.values())

data = {}
data["a"] = int(input("Enter first number: "))
data["b"] = int(input("Enter second number: "))

print(add(**data))  # unpacks dict as keyword arguments

# %%
def add(**kwargs):
    print(type(kwargs))   # <class 'dict'>
    print(kwargs)          # e.g. {'a': 10, 'b': 20, 'c': 30}
    total = 0
    for value in kwargs.values():
        total += value
    return total

print(add(a=10, b=20, c=30))  # Output: 60

# %%
def add(**kwargs):
    total = 0
    for key, value in kwargs.items():
        print(key, "->", value)
        total += value
    return total

print(add(a=10, b=20, c=30))

# %%
def add(**kwargs):
    total = 0
    for key in kwargs.keys():
        print(key, "->", kwargs[key])
        total += kwargs[key]
    return total

print(add(a=10, b=20, c=30))

# %% [markdown]
# in the below program
# function returns two value

# %%
def division(a, b):
    if b != 0:
        return (a / b, a // b)
    else:
        print("Error: Cannot divide by zero.")
        return None

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

result = division(a, b)
print(type(result))
if result is not None:
    print(f"True division: {result[0]}, Floor division: {result[1]}")

# %%
#Sequence Unpacking
a,b=result
print(a,b)

# %%
#Sequence Packing
x=1,2,3,4,5
print(type(x),x)

# %%
#WAP using function to generate perfect numbers between 1 to 1000?

# %%
def is_perfect(num):
    """Return True if num is a perfect number (optimized version)."""
    if num < 2:
        return False
    
    divisor_sum = 1  # 1 is always a proper divisor
    i = 2
    while i * i <= num:
        if num % i == 0:
            divisor_sum += i
            partner = num // i
            if partner != i:
                divisor_sum += partner
        i += 1
    
    return divisor_sum == num


def find_perfect_numbers(start, end):
    return [num for num in range(start, end + 1) if is_perfect(num)]


print("Perfect numbers between 1 and 1000:", find_perfect_numbers(1, 1000))

# %%
s = input("ENter the WOrd =")

for i in range(len(s)):
    print(s[i])

# %%
t = (10, 20, 30, 40, 50)     #Tuple traversing 
for i in t:
    print(i)

# %%
t = (10, 20, 30, 40, 50)

print(t[1:4])     # (20, 30, 40)
print(t[:3])      # (10, 20, 30)
print(t[2:])      # (30, 40, 50)
print(t[:])       # (10, 20, 30, 40, 50)
print(t[::2])     # (10, 30, 50)
print(t[1::2])    # (20, 40)
print(t[::-1])    # (50, 40, 30, 20, 10)

# %%
d = {                              #Dictinary traversing and slicing
    "name": "Aryan",
    "age": 20,
    "course": "CSE"
}
for i in d:
    print(i)

# %%
for i in d.values():
    print(i)

# %%
def convert_temp(temp,unit):
    if unit=='C':
        return temp*9/5+32 #chnages from celsius to fahrenheit
    elif unit=='F':
        return (temp-32)*5/9   # changes to celsius from Fahrenheit 
    else:
        return None
print(convert_temp(25,'C'))
print(convert_temp(75,'F'))

# %%
a=int(input("Enter starting number: "))
b=int(input("Enter ending number: "))
for n in range(a,b+1):
    s=0
    for i in range(1,n):
        if n%i==0:
            s+=i
    if s==n:
        print(n)

# %%
password=input("Enter password: ")
upper=0
lower=0
digit=0
special=0
for i in password:
    if i.isupper():
        upper=1
    elif i.islower():
        lower=1
    elif i.isdigit():
        digit=1
    else:
        special=1
if len(password)>=8 and upper==1 and lower==1 and digit==1 and special==1:
    print("Strong Password")
else:
    print("Weak Password")

# %%
#Calculate the Total Cost of Items in a Shopping Cart
def total_cost():
    n=int(input("Enter number of items: "))
    total=0
    for i in range(n):
        name=input("Enter The item")
        price=float(input("Enter price: "))
        quantity=int(input("Enter quantity: "))
        total=total+price*quantity
    print(name,"=","Total Cost =",total)
total_cost()

# %%
s1=input("Enter the Word= ")
print(s1[0])
print(s1[:3])
print(s1[2::1])

# %%
s1[2:8:2]

# %%
s1="HEllo Python"
for i in range(10):
    print(s1[i])
print(s1[: :-1])

# %% [markdown]
# s1[a:b:c] **a=start, b=stop, c=step**
# **c {step value} determines the forward or backward indexing **

# %%
s = "hello world python"

print("Original:", s)
print("Capitalize:", s.capitalize())
print("Title:", s.title())
print("Upper:", s.upper())
print("Lower:", s.lower())
print("Replace:", s.replace("python", "java"))

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

n = int(input("Enter number: "))

print("Factorial =", factorial(n))

# %%
def palindrome(s):
    if s == s[::-1]:
        return "Palindrome"
    else:
        return "Not Palindrome"

s = input("Enter string: ")

print(palindrome(s))

# %% [markdown]
# **Lambda Function in Python**
#
# A lambda function is a small anonymous function written in a single line.
# *they can have many number of arguments but only one expression*

# %%
add = lambda a, b: a + b

print(add(10, 20))

# %%
even = lambda x: x % 2 == 0

print(even(10))

# %%
numbers = [1, 2, 3, 4, 5]

result = list(map(lambda x: x * 2, numbers))

print(result)

# %%
x=[1,2,3,4,5,6]
def square(x):
    return x * x

(square(51))

# %% [markdown]
# **Filter Function**

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = filter(lambda x: x % 2 == 0, numbers)
print(list(result))

# %%
def is_even(x):
    return x % 2 == 0
numbers = [1, 2, 3, 4, 5, 6]
result = filter(is_even, numbers)
print(list(result))

# %%
def even(num):
    if num%2==0:
        return True
    return False

# %%
even(31)

# %%
a=[1,3,5,7,9,2,6]
result=filter(lambda x:x>5,a)
print(list(result))

# %%
a=[2,5,7,9,10,12,15]
result=filter(lambda x:x>5 and x<10,a)
print(list(result))

# %%
people=[
    {"name":"Aryan","age":21},
    {"name":"Rahul","age":27},
    {"name":"Aman","age":30},
    {"name":"Raj","age":22}]
result=filter(lambda x:x["age"]>25,people)
print(list(result))

# %% [markdown]
# # ZIP()

# %%
names=["Aryan","Rahul","Aman"]
scores=[21,22,23]
result=zip(names,scores)
print(list(result))

# %%
from itertools import zip_longest
a=[1,2,3,4]
b=["A","B"]
print(list(zip_longest(a,b)))
